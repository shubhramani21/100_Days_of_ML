# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Nagpur_restaurant.csv")

# %%
df
# Out:
#      Unnamed: 0                           Name  Rating  \
# 0             0    Moti Mahal Delux Restaurant     4.4
# 1             1  Corridor Seven Coffee Roaster     5.0
# 2             2               Jagat Restaurant     5.0
# 3             3                      Kalpataru     3.9
# 4             4                      Side Walk     3.8
# ..          ...                            ...     ...
# 812         812                    Spice Magic     NaN
# 813         813                        Tauby's     NaN
# 814         814        The Biryani Destination     NaN
# 815         815    Dineout SteppinOut Cookbook     NaN
# 816         816                        Singh's     NaN
#
#                                         Cuisine                 Avg Rate  \
# 0                North Indian, Mughlai, Biryani    ₹ 900 for 2 (approx)
# 1                         Desserts, Continental    ₹ 800 for 2 (approx)
# 2     North Indian, Chinese, Pizza, Street Food    ₹ 600 for 2 (approx)
# ...

# %%
len(df[df['Rating']>4])
# Out:
#      Unnamed: 0                           Name  Rating  \
# 0             0    Moti Mahal Delux Restaurant     4.4
# 1             1  Corridor Seven Coffee Roaster     5.0
# 2             2               Jagat Restaurant     5.0
# 5             5                Barbeque Nation     4.3
# 7             7                       Robo 2.0     4.3
# ..          ...                            ...     ...
# 637         637             Haldiram's Express     5.0
# 784         784                Hotel City Line     5.0
# 793         793                     Singh Saab     4.8
# 802         802                  Kairos Restro     4.5
# 803         803                   Chokar Dhani     5.0
#
#                                                Cuisine  \
# 0                       North Indian, Mughlai, Biryani
# 1                                Desserts, Continental
# 2            North Indian, Chinese, Pizza, Street Food
# 5                                North Indian, Chinese
# ...
