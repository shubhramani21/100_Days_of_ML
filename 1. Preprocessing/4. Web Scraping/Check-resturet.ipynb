# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Nagpur_restaurant.csv")

# %%
df
# Out:
#      Unnamed: 0                           Name  Rating  \
# 0             0    Moti Mahal Delux Restaurant     4.4
# 1             1  Corridor Seven Coffee Roaster     5.0
# 2             2               Jagat Restaurant     5.0
# 3             3                      Kalpataru     3.9
# 4             4                      Side Walk     3.8
# ..          ...                            ...     ...
# 812         812                    Spice Magic     NaN
# 813         813                        Tauby's     NaN
# 814         814        The Biryani Destination     NaN
# 815         815    Dineout SteppinOut Cookbook     NaN
# 816         816                        Singh's     NaN
#
#                                         Cuisine                 Avg Rate  \
# 0                North Indian, Mughlai, Biryani    ₹ 900 for 2 (approx)
# 1                         Desserts, Continental    ₹ 800 for 2 (approx)
# 2     North Indian, Chinese, Pizza, Street Food    ₹ 600 for 2 (approx)
# ...

# %%
df1=df[df['Rating']>4]

# %%
df1.to_csv("Top_Restaurent.csv",index=False)
