# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=350d9555d777e2abfbc466e83e8fb0d2&language=en-US&page=1')

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','original_language','release_date','popularity','vote_average','vote_count']]

# %%
df
# Out:
#         id                                          title original_language  \
# 0      238                                  The Godfather                en
# 1      278                       The Shawshank Redemption                en
# 2      240                          The Godfather Part II                en
# 3      424                               Schindler's List                en
# 4    19404                    Dilwale Dulhania Le Jayenge                hi
# 5      129                                  Spirited Away                ja
# 6      389                                   12 Angry Men                en
# 7   372058                                     Your Name.                ja
# 8   496243                                       Parasite                ko
# 9      155                                The Dark Knight                en
# 10     497                                 The Green Mile                en
# ...

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,570):
    response=requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=350d9555d777e2abfbc466e83e8fb0d2&language=en-US&page={i}') 
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','original_language','release_date','popularity','vote_average','vote_count']]
    df=df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_29308\3816813619.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_29308\3816813619.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_29308\3816813619.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_29308\3816813619.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# ...

# %%
df
# Out:
#           id                          title original_language release_date  \
# 0        238                  The Godfather                en   1972-03-14
# 1        278       The Shawshank Redemption                en   1994-09-23
# 2        240          The Godfather Part II                en   1974-12-20
# 3        424               Schindler's List                en   1993-12-15
# 4      19404    Dilwale Dulhania Le Jayenge                hi   1995-10-20
# ...      ...                            ...               ...          ...
# 9995    2210           Earth Girls Are Easy                en   1988-09-08
# 9996  139567                 Fire with Fire                en   2012-08-31
# 9997   24271               The Maiden Heist                en   2009-05-09
# 9998   18298                The Three Kings                fr   2001-12-12
# 9999   16337  The Texas Chainsaw Massacre 2                en   1986-08-22
#
#       popularity  vote_average  vote_count
# ...

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=350d9555d777e2abfbc466e83e8fb0d2&language=en-US&page=569') 
try:
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','original_language','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df, ignore_index=True)
except KeyError:
    print("Key 'results' not found in the API response.")
# Out:
# Key 'results' not found in the API response.

# %%
df.to_csv("movies.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  int64
#  1   title              10000 non-null  object
#  2   original_language  10000 non-null  object
#  3   release_date       10000 non-null  object
#  4   popularity         10000 non-null  float64
#  5   vote_average       10000 non-null  float64
#  6   vote_count         10000 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 547.0+ KB

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  int64
#  1   title              10000 non-null  object
#  2   original_language  10000 non-null  object
#  3   release_date       10000 non-null  datetime64[ns]
#  4   popularity         10000 non-null  float64
#  5   vote_average       10000 non-null  float64
#  6   vote_count         10000 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 547.0+ KB

# %%
df.to_csv("movies.csv")

# %%
# Out:
# {'message': 'You are not subscribed to this API.'}
